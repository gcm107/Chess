# %% [markdown]
# Monte Carlo Tree Search (MCTS) without neural networks:
#
#    This is a search algorithm that can be used to create strong chess engines without relying on deep learning. It involves simulating many possible future game states and choosing moves based on these simulations.

# %%
import os
import sys
src_path = os.path.abspath(os.path.join(os.path.dirname('__file__'), '..', 'src'))
sys.path.append(src_path)
import chess
import json
import chess
import math
from stockfish import Stockfish
import chess.svg
from IPython.display import SVG, display, clear_output
from chess_zero.config import Config, PlayWithHumanConfig
from chess_zero.agent.model_chess import ChessModel
from chess_zero.agent.player_chess import ChessPlayer
import numpy as np
import random
from chess_zero.env.chess_env import ChessEnv
from chess_zero.agent.model_chess import ChessModel
from chess_zero.lib.model_helper import load_best_model_weight
# Out:
# 2024-09-25 23:03:27.980716: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-25 23:03:27.992406: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-25 23:03:27.996790: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-25 23:03:28.006203: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-25 23:03:28.684003: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import time
class Node:
    def __init__(self, state, parent=None, move=None):
        self.state = state
        self.parent = parent
        self.move = move
        self.children = []
        self.visits = 0
        self.value = 0

class MCTS:
    def __init__(self, root_state, exploration_weight=1.4):
        self.root = Node(root_state)
        self.exploration_weight = exploration_weight

    def select(self, node):
        while node.children:
            if not all(child.visits > 0 for child in node.children):
                return self.expand(node)
            node = self.uct_select(node)
        return node

    def expand(self, node):
        for move in node.state.legal_moves:
            new_state = node.state.copy()
            new_state.push(move)
            child = Node(new_state, parent=node, move=move)
            node.children.append(child)
        return random.choice(node.children)

    def simulate(self, node):
        state = node.state.copy()
        while not state.is_game_over():
            move = random.choice(list(state.legal_moves))
            state.push(move)
        return self.get_result(state)

    def backpropagate(self, node, result):
        while node is not None:
            node.visits += 1
            node.value += result
            node = node.parent

    def uct_select(self, node):
        return max(node.children, key=lambda c: self.uct_value(c))

    def uct_value(self, node):
        if node.visits == 0:
            return float('inf')
        return (node.value / node.visits) + self.exploration_weight * math.sqrt(
            math.log(node.parent.visits) / node.visits)

    def get_result(self, state):
        if state.is_checkmate():
            return 1 if state.turn == chess.BLACK else -1
        elif state.is_stalemate() or state.is_insufficient_material() or state.is_seventyfive_moves() or state.is_fivefold_repetition():
            return 0
        else:
            return 0  # This shouldn't happen in a completed game

    def search(self, num_simulations):
        legal_moves = list(self.root.state.legal_moves)
        for move in legal_moves:
            self.expand_move(self.root, move)
        
        for _ in range(max(num_simulations - len(legal_moves), 0)):
            leaf = self.select(self.root)
            result = self.simulate(leaf)
            self.backpropagate(leaf, result)

    def expand_move(self, node, move):
        new_state = node.state.copy()
        new_state.push(move)
        child = Node(new_state, parent=node, move=move)
        node.children.append(child)
        result = self.simulate(child)
        self.backpropagate(child, result)

    def best_move(self):
        if not self.root.children:
            return random.choice(list(self.root.state.legal_moves))
        return max(self.root.children, key=lambda c: c.visits).move

def play_game():
    board = chess.Board()
    mcts = MCTS(board)

    while not board.is_game_over():
        if board.turn == chess.WHITE:
            start_time = time.time()
            while time.time() - start_time < 5:  # 5 seconds time limit
                mcts.search(100)  # Run in smaller batches
            move = mcts.best_move()
            if move is None:
                print("MCTS couldn't find a move. Resigning.")
                break
        else:
            # play against stockfish third best move
            stockfish = Stockfish(path="/usr/games/stockfish")
            stockfish.set_fen_position(board.fen())
            moves = stockfish.get_top_moves(3)
            print(f"Top 3 moves: {moves}")
            if not moves:
                print("Stockfish couldn't find a move. Resigning.")
                break
            move = chess.Move.from_uci(moves[2]['Move'])
        
        print(f"{'White' if board.turn == chess.WHITE else 'Black'} plays: {move}")
        board.push(move)
        print(board)
        print("\n")

        # Update MCTS root for the next turn
        if not board.is_game_over():
            if mcts.root.children:
                mcts.root = next((child for child in mcts.root.children if child.move == move), None)
                if mcts.root is None:
                    mcts.root = Node(board)
                else:
                    mcts.root.parent = None
            else:
                mcts.root = Node(board)

    print("Game Over")
    print("Result:", board.result())

if __name__ == "__main__":
    play_game()
# Out:
# White plays: e2e4
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
#
#
# Top 3 moves: [{'Move': 'c7c5', 'Centipawn': 34, 'Mate': None}, {'Move': 'c7c6', 'Centipawn': 46, 'Mate': None}, {'Move': 'e7e6', 'Centipawn': 51, 'Mate': None}]
# Black plays: e7e6
# r n b q k b n r
# p p p p . p p p
# . . . . p . . .
# . . . . . . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
#
#
# White plays: d1g4
# r n b q k b n r
# p p p p . p p p
# . . . . p . . .
# . . . . . . . .
# . . . . P . Q .
# . . . . . . . .
# P P P P . P P P
# R N B . K B N R
#
#
# Top 3 moves: [{'Move': 'd7d5', 'Centipawn': -62, 'Mate': None}, {'Move': 'b8c6', 'Centipawn': -53, 'Mate': None}, {'Move': 'c7c5', 'Centipawn': -50, 'Mate': None}]
# Black plays: c7c5
# r n b q k b n r
# p p . p . p p p
# . . . . p . . .
# . . p . . . . .
# . . . . P . Q .
# . . . . . . . .
# P P P P . P P P
# R N B . K B N R
#
#
# White plays: g4g7
# r n b q k b n r
# p p . p . p Q p
# . . . . p . . .
# . . p . . . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R N B . K B N R
#
#
# Top 3 moves: [{'Move': 'f8g7', 'Centipawn': -1180, 'Mate': None}, {'Move': 'd8f6', 'Centipawn': 149, 'Mate': None}, {'Move': 'd7d5', 'Centipawn': 814, 'Mate': None}]
# Black plays: d7d5
# r n b q k b n r
# p p . . . p Q p
# . . . . p . . .
# . . p p . . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R N B . K B N R
#
#
# White plays: f2f4
# r n b q k b n r
# p p . . . p Q p
# . . . . p . . .
# . . p p . . . .
# . . . . P P . .
# . . . . . . . .
# P P P P . . P P
# R N B . K B N R
#
#
# Top 3 moves: [{'Move': 'f8g7', 'Centipawn': -1178, 'Mate': None}, {'Move': 'd8h4', 'Centipawn': 107, 'Mate': None}, {'Move': 'd8f6', 'Centipawn': 165, 'Mate': None}]
# Black plays: d8f6
# r n b . k b n r
# p p . . . p Q p
# . . . . p q . .
# . . p p . . . .
# . . . . P P . .
# . . . . . . . .
# P P P P . . P P
# R N B . K B N R
#
#
# White plays: e4e5
# r n b . k b n r
# p p . . . p Q p
# . . . . p q . .
# . . p p P . . .
# . . . . . P . .
# . . . . . . . .
# P P P P . . P P
# R N B . K B N R
#
#
# Top 3 moves: [{'Move': 'f6g7', 'Centipawn': -1171, 'Mate': None}, {'Move': 'f8g7', 'Centipawn': -137, 'Mate': None}, {'Move': 'f6h4', 'Centipawn': 131, 'Mate': None}]
# Black plays: f6h4
# r n b . k b n r
# p p . . . p Q p
# . . . . p . . .
# . . p p P . . .
# . . . . . P . q
# . . . . . . . .
# P P P P . . P P
# R N B . K B N R
#
#
# White plays: g2g3
# r n b . k b n r
# p p . . . p Q p
# . . . . p . . .
# . . p p P . . .
# . . . . . P . q
# . . . . . . P .
# P P P P . . . P
# R N B . K B N R
#
#
# Top 3 moves: [{'Move': 'f8g7', 'Centipawn': -18, 'Mate': None}, {'Move': 'h4h6', 'Centipawn': 769, 'Mate': None}, {'Move': 'g8e7', 'Centipawn': 813, 'Mate': None}]
# Black plays: g8e7
# r n b . k b . r
# p p . . n p Q p
# . . . . p . . .
# . . p p P . . .
# . . . . . P . q
# . . . . . . P .
# P P P P . . . P
# R N B . K B N R
#
#
# White plays: g7g8
# r n b . k b Q r
# p p . . n p . p
# . . . . p . . .
# . . p p P . . .
# . . . . . P . q
# . . . . . . P .
# P P P P . . . P
# R N B . K B N R
#
#
# Top 3 moves: [{'Move': 'h8g8', 'Centipawn': -137, 'Mate': None}, {'Move': 'e7g8', 'Centipawn': -23, 'Mate': None}, {'Move': 'h4h6', 'Centipawn': 555, 'Mate': None}]
# Black plays: h4h6
# r n b . k b Q r
# p p . . n p . p
# . . . . p . . q
# . . p p P . . .
# . . . . . P . .
# . . . . . . P .
# P P P P . . . P
# R N B . K B N R
#
#
# White plays: g8g6
# r n b . k b . r
# p p . . n p . p
# . . . . p . Q q
# . . p p P . . .
# . . . . . P . .
# . . . . . . P .
# P P P P . . . P
# R N B . K B N R
#
#
# Top 3 moves: [{'Move': 'h7g6', 'Centipawn': -1184, 'Mate': None}, {'Move': 'h6g6', 'Centipawn': -1164, 'Mate': None}, {'Move': 'e7g6', 'Centipawn': -1154, 'Mate': None}]
# Black plays: e7g6
# r n b . k b . r
# p p . . . p . p
# . . . . p . n q
# . . p p P . . .
# . . . . . P . .
# . . . . . . P .
# P P P P . . . P
# R N B . K B N R
#
#
# White plays: f1d3
# r n b . k b . r
# p p . . . p . p
# . . . . p . n q
# . . p p P . . .
# . . . . . P . .
# . . . B . . P .
# P P P P . . . P
# R N B . K . N R
#
#
# Top 3 moves: [{'Move': 'b8c6', 'Centipawn': -1184, 'Mate': None}, {'Move': 'f8e7', 'Centipawn': -1176, 'Mate': None}, {'Move': 'c8d7', 'Centipawn': -1176, 'Mate': None}]
# Black plays: c8d7
# r n . . k b . r
# p p . b . p . p
# . . . . p . n q
# . . p p P . . .
# . . . . . P . .
# . . . B . . P .
# P P P P . . . P
# R N B . K . N R
#
#
# White plays: d3b5
# r n . . k b . r
# p p . b . p . p
# . . . . p . n q
# . B p p P . . .
# . . . . . P . .
# . . . . . . P .
# P P P P . . . P
# R N B . K . N R
#
#
# Top 3 moves: [{'Move': 'd7b5', 'Centipawn': -1620, 'Mate': None}, {'Move': 'g6e5', 'Centipawn': -1238, 'Mate': None}, {'Move': 'b8c6', 'Centipawn': -1187, 'Mate': None}]
# Black plays: b8c6
# r . . . k b . r
# p p . b . p . p
# . . n . p . n q
# . B p p P . . .
# . . . . . P . .
# . . . . . . P .
# P P P P . . . P
# R N B . K . N R
#
#
# White plays: b5c4
# r . . . k b . r
# p p . b . p . p
# . . n . p . n q
# . . p p P . . .
# . . B . . P . .
# . . . . . . P .
# P P P P . . . P
# R N B . K . N R
#
#
# Top 3 moves: [{'Move': 'd5c4', 'Centipawn': -1618, 'Mate': None}, {'Move': 'c6d4', 'Centipawn': -1500, 'Mate': None}, {'Move': 'c6b4', 'Centipawn': -1349, 'Mate': None}]
# Black plays: c6b4
# r . . . k b . r
# p p . b . p . p
# . . . . p . n q
# . . p p P . . .
# . n B . . P . .
# . . . . . . P .
# P P P P . . . P
# R N B . K . N R
#
#
# White plays: c4a6
# r . . . k b . r
# p p . b . p . p
# B . . . p . n q
# . . p p P . . .
# . n . . . P . .
# . . . . . . P .
# P P P P . . . P
# R N B . K . N R
#
#
# Top 3 moves: [{'Move': 'b4c2', 'Centipawn': -1745, 'Mate': None}, {'Move': 'b7a6', 'Centipawn': -1637, 'Mate': None}, {'Move': 'b4a6', 'Centipawn': -1629, 'Mate': None}]
# Black plays: b4a6
# r . . . k b . r
# p p . b . p . p
# n . . . p . n q
# . . p p P . . .
# . . . . . P . .
# . . . . . . P .
# P P P P . . . P
# R N B . K . N R
#
#
# White plays: g1e2
# r . . . k b . r
# p p . b . p . p
# n . . . p . n q
# . . p p P . . .
# . . . . . P . .
# . . . . . . P .
# P P P P N . . P
# R N B . K . . R
#
#
# Top 3 moves: [{'Move': 'a6b4', 'Centipawn': -1698, 'Mate': None}, {'Move': 'h6h3', 'Centipawn': -1692, 'Mate': None}, {'Move': 'e8c8', 'Centipawn': -1667, 'Mate': None}]
# Black plays: e8c8
# . . k r . b . r
# p p . b . p . p
# n . . . p . n q
# . . p p P . . .
# . . . . . P . .
# . . . . . . P .
# P P P P N . . P
# R N B . K . . R
#
#
# White plays: e1g1
# . . k r . b . r
# p p . b . p . p
# n . . . p . n q
# . . p p P . . .
# . . . . . P . .
# . . . . . . P .
# P P P P N . . P
# R N B . . R K .
#
#
# Top 3 moves: [{'Move': 'a6b4', 'Centipawn': -1713, 'Mate': None}, {'Move': 'h6h5', 'Centipawn': -1692, 'Mate': None}, {'Move': 'c5c4', 'Centipawn': -1669, 'Mate': None}]
# Black plays: c5c4
# . . k r . b . r
# p p . b . p . p
# n . . . p . n q
# . . . p P . . .
# . . p . . P . .
# . . . . . . P .
# P P P P N . . P
# R N B . . R K .
#
#
# White plays: a2a3
# . . k r . b . r
# p p . b . p . p
# n . . . p . n q
# . . . p P . . .
# . . p . . P . .
# P . . . . . P .
# . P P P N . . P
# R N B . . R K .
#
#
# Top 3 moves: [{'Move': 'f8c5', 'Centipawn': -1812, 'Mate': None}, {'Move': 'h6h5', 'Centipawn': -1797, 'Mate': None}, {'Move': 'f7f6', 'Centipawn': -1692, 'Mate': None}]
# Black plays: f7f6
# . . k r . b . r
# p p . b . . . p
# n . . . p p n q
# . . . p P . . .
# . . p . . P . .
# P . . . . . P .
# . P P P N . . P
# R N B . . R K .
#
#
# White plays: f1f2
# . . k r . b . r
# p p . b . . . p
# n . . . p p n q
# . . . p P . . .
# . . p . . P . .
# P . . . . . P .
# . P P P N R . P
# R N B . . . K .
#
#
# Top 3 moves: [{'Move': 'f8c5', 'Centipawn': -1997, 'Mate': None}, {'Move': 'h6h5', 'Centipawn': -1700, 'Mate': None}, {'Move': 'f6e5', 'Centipawn': -1669, 'Mate': None}]
# Black plays: f6e5
# . . k r . b . r
# p p . b . . . p
# n . . . p . n q
# . . . p p . . .
# . . p . . P . .
# P . . . . . P .
# . P P P N R . P
# R N B . . . K .
#
#
# White plays: f2f3
# . . k r . b . r
# p p . b . . . p
# n . . . p . n q
# . . . p p . . .
# . . p . . P . .
# P . . . . R P .
# . P P P N . . P
# R N B . . . K .
#
#
# Top 3 moves: [{'Move': 'f8c5', 'Centipawn': -2153, 'Mate': None}, {'Move': 'h6h5', 'Centipawn': -2130, 'Mate': None}, {'Move': 'e5e4', 'Centipawn': -1938, 'Mate': None}]
# Black plays: e5e4
# . . k r . b . r
# p p . b . . . p
# n . . . p . n q
# . . . p . . . .
# . . p . p P . .
# P . . . . R P .
# . P P P N . . P
# R N B . . . K .
#
#
# White plays: c2c3
# . . k r . b . r
# p p . b . . . p
# n . . . p . n q
# . . . p . . . .
# . . p . p P . .
# P . P . . R P .
# . P . P N . . P
# R N B . . . K .
#
#
# Top 3 moves: [{'Move': 'e4f3', 'Centipawn': -2823, 'Mate': None}, {'Move': 'f8c5', 'Centipawn': -2353, 'Mate': None}, {'Move': 'e6e5', 'Centipawn': -2076, 'Mate': None}]
# Black plays: e6e5
# . . k r . b . r
# p p . b . . . p
# n . . . . . n q
# . . . p p . . .
# . . p . p P . .
# P . P . . R P .
# . P . P N . . P
# R N B . . . K .
#
#
# White plays: g1h1
# . . k r . b . r
# p p . b . . . p
# n . . . . . n q
# . . . p p . . .
# . . p . p P . .
# P . P . . R P .
# . P . P N . . P
# R N B . . . . K
#
#
# Top 3 moves: [{'Move': 'e4f3', 'Centipawn': -2878, 'Mate': None}, {'Move': 'f8c5', 'Centipawn': -2115, 'Mate': None}, {'Move': 'd5d4', 'Centipawn': -2038, 'Mate': None}]
# Black plays: d5d4
# . . k r . b . r
# p p . b . . . p
# n . . . . . n q
# . . . . p . . .
# . . p p p P . .
# P . P . . R P .
# . P . P N . . P
# R N B . . . . K
#
#
# White plays: f3e3
# . . k r . b . r
# p p . b . . . p
# n . . . . . n q
# . . . . p . . .
# . . p p p P . .
# P . P . R . P .
# . P . P N . . P
# R N B . . . . K
#
#
# Top 3 moves: [{'Move': 'd4e3', 'Centipawn': -2392, 'Mate': None}, {'Move': 'h6h3', 'Centipawn': -2279, 'Mate': None}, {'Move': 'e5f4', 'Centipawn': -2123, 'Mate': None}]
# Black plays: e5f4
# . . k r . b . r
# p p . b . . . p
# n . . . . . n q
# . . . . . . . .
# . . p p p p . .
# P . P . R . P .
# . P . P N . . P
# R N B . . . . K
#
#
# White plays: c3d4
# . . k r . b . r
# p p . b . . . p
# n . . . . . n q
# . . . . . . . .
# . . p P p p . .
# P . . . R . P .
# . P . P N . . P
# R N B . . . . K
#
#
# Top 3 moves: [{'Move': 'h6h3', 'Centipawn': -2423, 'Mate': None}, {'Move': 'f4e3', 'Centipawn': -2043, 'Mate': None}, {'Move': 'f4f3', 'Centipawn': -1979, 'Mate': None}]
# Black plays: f4f3
# . . k r . b . r
# p p . b . . . p
# n . . . . . n q
# . . . . . . . .
# . . p P p . . .
# P . . . R p P .
# . P . P N . . P
# R N B . . . . K
#
#
# White plays: e3e4
# . . k r . b . r
# p p . b . . . p
# n . . . . . n q
# . . . . . . . .
# . . p P R . . .
# P . . . . p P .
# . P . P N . . P
# R N B . . . . K
#
#
# Top 3 moves: [{'Move': 'h6h3', 'Centipawn': None, 'Mate': -2}, {'Move': 'd7c6', 'Centipawn': -2451, 'Mate': None}, {'Move': 'f3e2', 'Centipawn': -2186, 'Mate': None}]
# Black plays: f3e2
# . . k r . b . r
# p p . b . . . p
# n . . . . . n q
# . . . . . . . .
# . . p P R . . .
# P . . . . . P .
# . P . P p . . P
# R N B . . . . K
#
#
# White plays: e4e7
# . . k r . b . r
# p p . b R . . p
# n . . . . . n q
# . . . . . . . .
# . . p P . . . .
# P . . . . . P .
# . P . P p . . P
# R N B . . . . K
#
#
# Top 3 moves: [{'Move': 'g6e7', 'Centipawn': None, 'Mate': -5}, {'Move': 'f8e7', 'Centipawn': None, 'Mate': -5}, {'Move': 'd7c6', 'Centipawn': -4930, 'Mate': None}]
# Black plays: d7c6
# . . k r . b . r
# p p . . R . . p
# n . b . . . n q
# . . . . . . . .
# . . p P . . . .
# P . . . . . P .
# . P . P p . . P
# R N B . . . . K
#
#
# White plays: d4d5
# . . k r . b . r
# p p . . R . . p
# n . b . . . n q
# . . . P . . . .
# . . p . . . . .
# P . . . . . P .
# . P . P p . . P
# R N B . . . . K
#
#
# Top 3 moves: [{'Move': 'f8e7', 'Centipawn': None, 'Mate': -5}, {'Move': 'g6e7', 'Centipawn': None, 'Mate': -5}, {'Move': 'c6d5', 'Centipawn': None, 'Mate': -5}]
# Black plays: c6d5
# . . k r . b . r
# p p . . R . . p
# n . . . . . n q
# . . . b . . . .
# . . p . . . . .
# P . . . . . P .
# . P . P p . . P
# R N B . . . . K
#
#
# White plays: h1g1
# . . k r . b . r
# p p . . R . . p
# n . . . . . n q
# . . . b . . . .
# . . p . . . . .
# P . . . . . P .
# . P . P p . . P
# R N B . . . K .
#
#
# Top 3 moves: [{'Move': 'f8e7', 'Centipawn': None, 'Mate': -4}, {'Move': 'g6e7', 'Centipawn': None, 'Mate': -5}, {'Move': 'g6e5', 'Centipawn': None, 'Mate': -6}]
# Black plays: g6e5
# . . k r . b . r
# p p . . R . . p
# n . . . . . . q
# . . . b n . . .
# . . p . . . . .
# P . . . . . P .
# . P . P p . . P
# R N B . . . K .
#
#
# White plays: g3g4
# . . k r . b . r
# p p . . R . . p
# n . . . . . . q
# . . . b n . . .
# . . p . . . P .
# P . . . . . . .
# . P . P p . . P
# R N B . . . K .
#
#
# Top 3 moves: [{'Move': 'e2e1q', 'Centipawn': None, 'Mate': -1}, {'Move': 'e2e1r', 'Centipawn': None, 'Mate': -2}, {'Move': 'h6e3', 'Centipawn': None, 'Mate': -2}]
# Black plays: h6e3
# . . k r . b . r
# p p . . R . . p
# n . . . . . . .
# . . . b n . . .
# . . p . . . P .
# P . . . q . . .
# . P . P p . . P
# R N B . . . K .
#
#
# White plays: d2e3
# . . k r . b . r
# p p . . R . . p
# n . . . . . . .
# . . . b n . . .
# . . p . . . P .
# P . . . P . . .
# . P . . p . . P
# R N B . . . K .
#
#
# Top 3 moves: [{'Move': 'e2e1q', 'Centipawn': None, 'Mate': -1}, {'Move': 'e5f3', 'Centipawn': -3076, 'Mate': None}, {'Move': 'e2e1r', 'Centipawn': -3046, 'Mate': None}]
# Black plays: e2e1r
# . . k r . b . r
# p p . . R . . p
# n . . . . . . .
# . . . b n . . .
# . . p . . . P .
# P . . . P . . .
# . P . . . . . P
# R N B . r . K .
#
#
# White plays: g1f2
# . . k r . b . r
# p p . . R . . p
# n . . . . . . .
# . . . b n . . .
# . . p . . . P .
# P . . . P . . .
# . P . . . K . P
# R N B . r . . .
#
#
# Top 3 moves: [{'Move': 'e5d3', 'Centipawn': -3373, 'Mate': None}, {'Move': 'f8e7', 'Centipawn': -2269, 'Mate': None}, {'Move': 'e1c1', 'Centipawn': -2115, 'Mate': None}]
# Black plays: e1c1
# . . k r . b . r
# p p . . R . . p
# n . . . . . . .
# . . . b n . . .
# . . p . . . P .
# P . . . P . . .
# . P . . . K . P
# R N r . . . . .
#
#
# White plays: e7f7
# . . k r . b . r
# p p . . . R . p
# n . . . . . . .
# . . . b n . . .
# . . p . . . P .
# P . . . P . . .
# . P . . . K . P
# R N r . . . . .
#
#
# Top 3 moves: [{'Move': 'd5f7', 'Centipawn': -3160, 'Mate': None}, {'Move': 'c1c2', 'Centipawn': -2954, 'Mate': None}, {'Move': 'e5f7', 'Centipawn': -2953, 'Mate': None}]
# Black plays: e5f7
# . . k r . b . r
# p p . . . n . p
# n . . . . . . .
# . . . b . . . .
# . . p . . . P .
# P . . . P . . .
# . P . . . K . P
# R N r . . . . .
#
#
# White plays: b1c3
# . . k r . b . r
# p p . . . n . p
# n . . . . . . .
# . . . b . . . .
# . . p . . . P .
# P . N . P . . .
# . P . . . K . P
# R . r . . . . .
#
#
# Top 3 moves: [{'Move': 'c1a1', 'Centipawn': -3323, 'Mate': None}, {'Move': 'c1c2', 'Centipawn': -2838, 'Mate': None}, {'Move': 'a6c5', 'Centipawn': -2645, 'Mate': None}]
# Black plays: a6c5
# . . k r . b . r
# p p . . . n . p
# . . . . . . . .
# . . n b . . . .
# . . p . . . P .
# P . N . P . . .
# . P . . . K . P
# R . r . . . . .
#
#
# White plays: e3e4
# . . k r . b . r
# p p . . . n . p
# . . . . . . . .
# . . n b . . . .
# . . p . P . P .
# P . N . . . . .
# . P . . . K . P
# R . r . . . . .
#
#
# Top 3 moves: [{'Move': 'c5e4', 'Centipawn': -3038, 'Mate': None}, {'Move': 'c5d3', 'Centipawn': -2985, 'Mate': None}, {'Move': 'c1a1', 'Centipawn': -2976, 'Mate': None}]
# Black plays: c1a1
# . . k r . b . r
# p p . . . n . p
# . . . . . . . .
# . . n b . . . .
# . . p . P . P .
# P . N . . . . .
# . P . . . K . P
# r . . . . . . .
#
#
# White plays: c3b1
# . . k r . b . r
# p p . . . n . p
# . . . . . . . .
# . . n b . . . .
# . . p . P . P .
# P . . . . . . .
# . P . . . K . P
# r N . . . . . .
#
#
# Top 3 moves: [{'Move': 'a1b1', 'Centipawn': -8547, 'Mate': None}, {'Move': 'c5e4', 'Centipawn': -7926, 'Mate': None}, {'Move': 'd5e6', 'Centipawn': -7637, 'Mate': None}]
# Black plays: d5e6
# . . k r . b . r
# p p . . . n . p
# . . . . b . . .
# . . n . . . . .
# . . p . P . P .
# P . . . . . . .
# . P . . . K . P
# r N . . . . . .
#
#
# White plays: h2h4
# . . k r . b . r
# p p . . . n . p
# . . . . b . . .
# . . n . . . . .
# . . p . P . P P
# P . . . . . . .
# . P . . . K . .
# r N . . . . . .
#
#
# Top 3 moves: [{'Move': 'a1b1', 'Centipawn': None, 'Mate': -5}, {'Move': 'c5e4', 'Centipawn': None, 'Mate': -5}, {'Move': 'c5d3', 'Centipawn': None, 'Mate': -9}]
# Black plays: c5d3
# . . k r . b . r
# p p . . . n . p
# . . . . b . . .
# . . . . . . . .
# . . p . P . P P
# P . . n . . . .
# . P . . . K . .
# r N . . . . . .
#
#
# White plays: f2g2
# . . k r . b . r
# p p . . . n . p
# . . . . b . . .
# . . . . . . . .
# . . p . P . P P
# P . . n . . . .
# . P . . . . K .
# r N . . . . . .
#
#
# Top 3 moves: [{'Move': 'd3e1', 'Centipawn': -8620, 'Mate': None}, {'Move': 'a1b1', 'Centipawn': -8160, 'Mate': None}, {'Move': 'd3b2', 'Centipawn': -3992, 'Mate': None}]
# Black plays: d3b2
# . . k r . b . r
# p p . . . n . p
# . . . . b . . .
# . . . . . . . .
# . . p . P . P P
# P . . . . . . .
# . n . . . . K .
# r N . . . . . .
#
#
# White plays: g2g3
# . . k r . b . r
# p p . . . n . p
# . . . . b . . .
# . . . . . . . .
# . . p . P . P P
# P . . . . . K .
# . n . . . . . .
# r N . . . . . .
#
#
# Top 3 moves: [{'Move': 'a1b1', 'Centipawn': None, 'Mate': -5}, {'Move': 'd8d3', 'Centipawn': None, 'Mate': -6}, {'Move': 'f8d6', 'Centipawn': None, 'Mate': -8}]
# Black plays: f8d6
# . . k r . . . r
# p p . . . n . p
# . . . b b . . .
# . . . . . . . .
# . . p . P . P P
# P . . . . . K .
# . n . . . . . .
# r N . . . . . .
#
#
# White plays: g3h3
# . . k r . . . r
# p p . . . n . p
# . . . b b . . .
# . . . . . . . .
# . . p . P . P P
# P . . . . . . K
# . n . . . . . .
# r N . . . . . .
#
#
# Top 3 moves: [{'Move': 'd6f4', 'Centipawn': None, 'Mate': -4}, {'Move': 'a1b1', 'Centipawn': None, 'Mate': -5}, {'Move': 'd6e5', 'Centipawn': None, 'Mate': -5}]
# Black plays: d6e5
# . . k r . . . r
# p p . . . n . p
# . . . . b . . .
# . . . . b . . .
# . . p . P . P P
# P . . . . . . K
# . n . . . . . .
# r N . . . . . .
#
#
# White plays: h3g2
# . . k r . . . r
# p p . . . n . p
# . . . . b . . .
# . . . . b . . .
# . . p . P . P P
# P . . . . . . .
# . n . . . . K .
# r N . . . . . .
#
#
# Top 3 moves: [{'Move': 'e6g4', 'Centipawn': None, 'Mate': -4}, {'Move': 'a1b1', 'Centipawn': None, 'Mate': -5}, {'Move': 'a7a5', 'Centipawn': None, 'Mate': -6}]
# Black plays: a7a5
# . . k r . . . r
# . p . . . n . p
# . . . . b . . .
# p . . . b . . .
# . . p . P . P P
# P . . . . . . .
# . n . . . . K .
# r N . . . . . .
#
#
# White plays: g2f3
# . . k r . . . r
# . p . . . n . p
# . . . . b . . .
# p . . . b . . .
# . . p . P . P P
# P . . . . K . .
# . n . . . . . .
# r N . . . . . .
#
#
# Top 3 moves: [{'Move': 'd8d3', 'Centipawn': None, 'Mate': -5}, {'Move': 'a1b1', 'Centipawn': None, 'Mate': -5}, {'Move': 'd8d1', 'Centipawn': None, 'Mate': -6}]
# Black plays: d8d1
# . . k . . . . r
# . p . . . n . p
# . . . . b . . .
# p . . . b . . .
# . . p . P . P P
# P . . . . K . .
# . n . . . . . .
# r N . r . . . .
#
#
# White plays: g4g5
# . . k . . . . r
# . p . . . n . p
# . . . . b . . .
# p . . . b . P .
# . . p . P . . P
# P . . . . K . .
# . n . . . . . .
# r N . r . . . .
#
#
# Top 3 moves: [{'Move': 'f7g5', 'Centipawn': None, 'Mate': -5}, {'Move': 'd1f1', 'Centipawn': None, 'Mate': -5}, {'Move': 'a1b1', 'Centipawn': None, 'Mate': -5}]
# Black plays: a1b1
# . . k . . . . r
# . p . . . n . p
# . . . . b . . .
# p . . . b . P .
# . . p . P . . P
# P . . . . K . .
# . n . . . . . .
# . r . r . . . .
#
#
# White plays: f3g2
# . . k . . . . r
# . p . . . n . p
# . . . . b . . .
# p . . . b . P .
# . . p . P . . P
# P . . . . . . .
# . n . . . . K .
# . r . r . . . .
#
#
# Top 3 moves: [{'Move': 'h8d8', 'Centipawn': None, 'Mate': -3}, {'Move': 'd1d2', 'Centipawn': None, 'Mate': -3}, {'Move': 'e6g4', 'Centipawn': None, 'Mate': -3}]
# Black plays: e6g4
# . . k . . . . r
# . p . . . n . p
# . . . . . . . .
# p . . . b . P .
# . . p . P . b P
# P . . . . . . .
# . n . . . . K .
# . r . r . . . .
#
#
# White plays: a3a4
# . . k . . . . r
# . p . . . n . p
# . . . . . . . .
# p . . . b . P .
# P . p . P . b P
# . . . . . . . .
# . n . . . . K .
# . r . r . . . .
#
#
# Top 3 moves: [{'Move': 'd1d2', 'Centipawn': None, 'Mate': -1}, {'Move': 'd1g1', 'Centipawn': None, 'Mate': -2}, {'Move': 'b2d3', 'Centipawn': None, 'Mate': -2}]
# Black plays: b2d3
# . . k . . . . r
# . p . . . n . p
# . . . . . . . .
# p . . . b . P .
# P . p . P . b P
# . . . n . . . .
# . . . . . . K .
# . r . r . . . .
#
#
# White plays: g5g6
# . . k . . . . r
# . p . . . n . p
# . . . . . . P .
# p . . . b . . .
# P . p . P . b P
# . . . n . . . .
# . . . . . . K .
# . r . r . . . .
#
#
# Top 3 moves: [{'Move': 'b1b2', 'Centipawn': None, 'Mate': -1}, {'Move': 'd1g1', 'Centipawn': None, 'Mate': -1}, {'Move': 'd1d2', 'Centipawn': None, 'Mate': -1}]
# Black plays: d1d2
# . . k . . . . r
# . p . . . n . p
# . . . . . . P .
# p . . . b . . .
# P . p . P . b P
# . . . n . . . .
# . . . r . . K .
# . r . . . . . .
#
#
# Game Over
# Result: 0-1
